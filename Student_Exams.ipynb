# %% [markdown]
# <a href="https://colab.research.google.com/github/wesleykieu/machine-learning-portfolio/blob/main/Student_Exams.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import r2_score, mean_squared_error
import tensorflow as tf
from tensorflow import keras

# %% [markdown]
# ## Data Card:
# student_id – A unique code given to each student for identification.
#
# hours_studied – The number of hours a student studied before the exam.
#
# sleep_hours – The average number of hours the student slept daily.
#
# attendance_percent – The percentage of classes attended by the student.
#
# previous_scores – The marks a student obtained in previous tests or assessments.
#
# exam_score – The final exam score of the student, used as the main performance measure.

# %%
df = pd.read_csv('student_exam_scores.csv')
df.head()
# Out:
#   student_id  hours_studied  sleep_hours  attendance_percent  previous_scores  \
# 0       S001            8.0          8.8                72.1               45
# 1       S002            1.3          8.6                60.7               55
# 2       S003            4.0          8.2                73.7               86
# 3       S004            3.5          4.8                95.1               66
# 4       S005            9.1          6.4                89.8               71
#
#    exam_score
# 0        30.2
# 1        25.0
# 2        35.8
# 3        34.0
# 4        40.3

# %%
df.isnull().sum()
# Out:
# student_id            0
# hours_studied         0
# sleep_hours           0
# attendance_percent    0
# previous_scores       0
# exam_score            0
# dtype: int64

# %% [markdown]
# ## Data Preprocessing

# %%
# Shuffle Dataset
df = df.sample(frac=1, random_state=42).reset_index(drop=True)

# %%
# Seperate Features and Target and drop student ID
X = df.drop(['student_id', 'exam_score'], axis = 1)
y = df['exam_score']

# %%
# Split the dataset 70-20-10
X_temp, X_test, y_temp, y_test = train_test_split(
    X, y, test_size=0.1, random_state=42
)

X_train, X_val, y_train, y_val = train_test_split(
    X_temp, y_temp, test_size=0.222, random_state=42
)

# %%
# Feature Scaling
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_val_scaled = scaler.transform(X_val)
X_test_scaled = scaler.transform(X_test)

# %%
# Build model
model = keras.Sequential([
    keras.layers.Input(shape=(X_train.shape[1],)),
    keras.layers.Dense(64, activation='relu'),
    keras.layers.Dense(32, activation='relu'),
    keras.layers.Dense(1)
])

# %%
model.compile(
    optimizer='adam',
    loss='mse',
    metrics=['mae']
)

# %%
callbacks = [
    keras.callbacks.EarlyStopping(
        monitor='val_loss',
        patience=10,
        restore_best_weights=True
    )
]

# %%
history = model.fit(
    X_train_scaled, y_train,
    validation_data=(X_val_scaled, y_val),
    epochs=100,
    batch_size=32,
    callbacks=callbacks

)
# Out:
# Epoch 1/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 311ms/step - loss: 1251.7522 - mae: 34.6508 - val_loss: 1150.9980 - val_mae: 33.2869
# Epoch 2/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 1191.4635 - mae: 33.8117 - val_loss: 1132.4102 - val_mae: 33.0088
# Epoch 3/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 1161.0392 - mae: 33.2806 - val_loss: 1114.2372 - val_mae: 32.7346
# Epoch 4/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 1176.3857 - mae: 33.5899 - val_loss: 1096.3616 - val_mae: 32.4610
# Epoch 5/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 1166.7350 - mae: 33.4119 - val_loss: 1078.2781 - val_mae: 32.1809
# Epoch 6/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 1150.1068 - mae: 33.2150 - val_loss: 1059.5260 - val_mae: 31.8872
# Epoch 7/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 1131.4574 - mae: 32.9339 - val_loss: 1039.4489 - val_mae: 31.5701
# Epoch 8/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 1120.9781 - mae: 32.6827 - val_loss: 1017.9041 - val_mae: 31.2261
# Epoch 9/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 1096.5959 - mae: 32.2809 - val_loss: 994.6840 - val_mae: 30.8507
# Epoch 10/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 1045.3582 - mae: 31.4655 - val_loss: 969.5798 - val_mae: 30.4394
# Epoch 11/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 1024.7235 - mae: 31.2631 - val_loss: 942.3604 - val_mae: 29.9870
# Epoch 12/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 978.3298 - mae: 30.4731 - val_loss: 913.1143 - val_mae: 29.4935
# Epoch 13/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 1000.6883 - mae: 30.8466 - val_loss: 881.4769 - val_mae: 28.9510
# Epoch 14/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 983.6193 - mae: 30.4786 - val_loss: 847.3960 - val_mae: 28.3555
# Epoch 15/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 913.2420 - mae: 29.3062 - val_loss: 811.0826 - val_mae: 27.7058
# Epoch 16/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 851.6943 - mae: 28.3161 - val_loss: 772.6188 - val_mae: 27.0014
# Epoch 17/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 881.6008 - mae: 28.8318 - val_loss: 731.7495 - val_mae: 26.2365
# Epoch 18/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 764.3248 - mae: 26.6738 - val_loss: 688.8409 - val_mae: 25.4039
# Epoch 19/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 737.2603 - mae: 26.2557 - val_loss: 643.6453 - val_mae: 24.5017
# Epoch 20/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 708.6342 - mae: 25.6730 - val_loss: 596.9349 - val_mae: 23.5355
# Epoch 21/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 668.5002 - mae: 24.9639 - val_loss: 548.7421 - val_mae: 22.4962
# Epoch 22/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 600.5923 - mae: 23.4849 - val_loss: 499.9499 - val_mae: 21.3905
# Epoch 23/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 542.4617 - mae: 22.1279 - val_loss: 450.4833 - val_mae: 20.2109
# Epoch 24/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 499.1328 - mae: 21.3936 - val_loss: 400.8649 - val_mae: 18.9572
# Epoch 25/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 432.2798 - mae: 19.6434 - val_loss: 352.0489 - val_mae: 17.6412
# Epoch 26/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 412.1560 - mae: 19.1305 - val_loss: 304.4869 - val_mae: 16.2560
# Epoch 27/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 342.6412 - mae: 17.3117 - val_loss: 260.1718 - val_mae: 14.8656
# Epoch 28/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 304.2018 - mae: 16.1289 - val_loss: 218.8110 - val_mae: 13.4877
# Epoch 29/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 250.2705 - mae: 14.4566 - val_loss: 182.0184 - val_mae: 12.1551
# Epoch 30/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 190.1258 - mae: 12.5212 - val_loss: 148.9540 - val_mae: 10.8486
# Epoch 31/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 181.6922 - mae: 12.2205 - val_loss: 120.1452 - val_mae: 9.6105
# Epoch 32/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 137.0581 - mae: 10.3771 - val_loss: 96.3435 - val_mae: 8.4751
# Epoch 33/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 112.7218 - mae: 9.3349 - val_loss: 76.8663 - val_mae: 7.4458
# Epoch 34/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 96.7415 - mae: 8.4792 - val_loss: 61.8555 - val_mae: 6.5705
# Epoch 35/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 70.9712 - mae: 7.1768 - val_loss: 51.2052 - val_mae: 5.9068
# Epoch 36/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 56.1363 - mae: 6.2775 - val_loss: 43.9448 - val_mae: 5.5556
# Epoch 37/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 44.5849 - mae: 5.5087 - val_loss: 39.3617 - val_mae: 5.3461
# Epoch 38/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 45.0084 - mae: 5.4834 - val_loss: 36.7628 - val_mae: 5.1627
# Epoch 39/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 40.5255 - mae: 5.2771 - val_loss: 35.4266 - val_mae: 5.0958
# Epoch 40/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 36.9050 - mae: 4.9470 - val_loss: 34.8936 - val_mae: 5.0416
# Epoch 41/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 31.6938 - mae: 4.5730 - val_loss: 34.6891 - val_mae: 5.0136
# Epoch 42/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 30.3482 - mae: 4.3875 - val_loss: 34.5809 - val_mae: 4.9990
# Epoch 43/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 33.0476 - mae: 4.6251 - val_loss: 34.5498 - val_mae: 5.0215
# Epoch 44/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 29.9768 - mae: 4.3322 - val_loss: 34.2522 - val_mae: 5.0257
# Epoch 45/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 30.3638 - mae: 4.3540 - val_loss: 33.8771 - val_mae: 5.0145
# Epoch 46/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 29.6637 - mae: 4.3904 - val_loss: 33.4238 - val_mae: 4.9920
# Epoch 47/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 32.0299 - mae: 4.5650 - val_loss: 32.9673 - val_mae: 4.9644
# Epoch 48/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 32.1398 - mae: 4.5700 - val_loss: 32.5860 - val_mae: 4.9359
# Epoch 49/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 26.9799 - mae: 4.1891 - val_loss: 32.1949 - val_mae: 4.9045
# Epoch 50/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 30.7857 - mae: 4.4755 - val_loss: 31.8028 - val_mae: 4.8727
# Epoch 51/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 29.0770 - mae: 4.3481 - val_loss: 31.5568 - val_mae: 4.8542
# Epoch 52/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 30.7563 - mae: 4.4880 - val_loss: 31.3579 - val_mae: 4.8425
# Epoch 53/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 30.6386 - mae: 4.5376 - val_loss: 31.1462 - val_mae: 4.8257
# Epoch 54/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 29.9603 - mae: 4.4271 - val_loss: 30.9600 - val_mae: 4.8105
# Epoch 55/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 27.4918 - mae: 4.1580 - val_loss: 30.8276 - val_mae: 4.8016
# Epoch 56/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 29.6680 - mae: 4.4837 - val_loss: 30.6481 - val_mae: 4.7884
# Epoch 57/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 29.8019 - mae: 4.4131 - val_loss: 30.5565 - val_mae: 4.7861
# Epoch 58/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 27.8638 - mae: 4.3109 - val_loss: 30.3208 - val_mae: 4.7657
# Epoch 59/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 25.1019 - mae: 4.0205 - val_loss: 30.1663 - val_mae: 4.7540
# Epoch 60/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 29.6867 - mae: 4.4218 - val_loss: 29.9391 - val_mae: 4.7356
# Epoch 61/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 26.9071 - mae: 4.2246 - val_loss: 29.8437 - val_mae: 4.7286
# Epoch 62/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 28.3247 - mae: 4.3208 - val_loss: 29.7162 - val_mae: 4.7194
# Epoch 63/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 26.8948 - mae: 4.2070 - val_loss: 29.5756 - val_mae: 4.7076
# Epoch 64/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 26.9900 - mae: 4.1767 - val_loss: 29.4622 - val_mae: 4.6989
# Epoch 65/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 26.1452 - mae: 4.0998 - val_loss: 29.2159 - val_mae: 4.6758
# Epoch 66/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 25.4684 - mae: 4.0982 - val_loss: 29.0143 - val_mae: 4.6546
# Epoch 67/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 24.3245 - mae: 3.8731 - val_loss: 28.8646 - val_mae: 4.6419
# Epoch 68/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 24.5538 - mae: 3.9595 - val_loss: 28.8253 - val_mae: 4.6387
# Epoch 69/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 24.9194 - mae: 3.9260 - val_loss: 28.7607 - val_mae: 4.6268
# Epoch 70/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 22.7047 - mae: 3.7929 - val_loss: 28.6296 - val_mae: 4.6153
# Epoch 71/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 25.9500 - mae: 4.0694 - val_loss: 28.5082 - val_mae: 4.6029
# Epoch 72/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 24.1360 - mae: 3.9707 - val_loss: 28.3164 - val_mae: 4.5888
# Epoch 73/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 25.6537 - mae: 4.0391 - val_loss: 28.1259 - val_mae: 4.5789
# Epoch 74/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 24.9534 - mae: 4.0000 - val_loss: 27.8931 - val_mae: 4.5614
# Epoch 75/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 24.9891 - mae: 4.0329 - val_loss: 27.7666 - val_mae: 4.5523
# Epoch 76/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 23.8229 - mae: 3.8956 - val_loss: 27.6119 - val_mae: 4.5421
# Epoch 77/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 25.6789 - mae: 4.0810 - val_loss: 27.4422 - val_mae: 4.5257
# Epoch 78/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 24.4257 - mae: 3.8832 - val_loss: 27.2531 - val_mae: 4.5065
# Epoch 79/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 26.1062 - mae: 4.0228 - val_loss: 27.1679 - val_mae: 4.5040
# Epoch 80/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 24.5859 - mae: 3.9530 - val_loss: 27.0929 - val_mae: 4.4963
# Epoch 81/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 24.1748 - mae: 3.9565 - val_loss: 27.0538 - val_mae: 4.4943
# Epoch 82/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 23.6168 - mae: 3.8733 - val_loss: 26.9800 - val_mae: 4.4918
# Epoch 83/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 25.4758 - mae: 4.0596 - val_loss: 26.9235 - val_mae: 4.4876
# Epoch 84/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 24.3692 - mae: 3.9170 - val_loss: 26.8082 - val_mae: 4.4814
# Epoch 85/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 21.6325 - mae: 3.6940 - val_loss: 26.7209 - val_mae: 4.4764
# Epoch 86/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 23.3349 - mae: 3.7920 - val_loss: 26.6906 - val_mae: 4.4759
# Epoch 87/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 21.5932 - mae: 3.6740 - val_loss: 26.6149 - val_mae: 4.4671
# Epoch 88/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 24.3680 - mae: 3.9617 - val_loss: 26.5102 - val_mae: 4.4538
# Epoch 89/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 25.5967 - mae: 4.0299 - val_loss: 26.4991 - val_mae: 4.4538
# Epoch 90/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 23.0744 - mae: 3.7730 - val_loss: 26.4419 - val_mae: 4.4454
# Epoch 91/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 21.6297 - mae: 3.7115 - val_loss: 26.4734 - val_mae: 4.4427
# Epoch 92/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 21.5067 - mae: 3.6893 - val_loss: 26.3583 - val_mae: 4.4312
# Epoch 93/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 23.8450 - mae: 3.9136 - val_loss: 26.2765 - val_mae: 4.4220
# Epoch 94/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 21.9590 - mae: 3.7833 - val_loss: 26.1705 - val_mae: 4.4100
# Epoch 95/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 21.0373 - mae: 3.6370 - val_loss: 25.9172 - val_mae: 4.3931
# Epoch 96/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 23.9011 - mae: 3.8497 - val_loss: 25.6871 - val_mae: 4.3778
# Epoch 97/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 21.2801 - mae: 3.6717 - val_loss: 25.5615 - val_mae: 4.3698
# Epoch 98/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 20.1853 - mae: 3.5439 - val_loss: 25.4462 - val_mae: 4.3571
# Epoch 99/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 21.6121 - mae: 3.7040 - val_loss: 25.4515 - val_mae: 4.3587
# Epoch 100/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 23.2654 - mae: 3.8439 - val_loss: 25.3403 - val_mae: 4.3508

# %% [markdown]
# With a base line of 3 layers of 64, 32, 1, able to achieve a mae = ~4. Now with tuning hyperparameters,
